# %% [markdown]
# # Week:3 Data pre-processing

# %% [markdown]
# ### Objective:
# The objective of this assignment is to perform exploratory data analysis, data pre-processing, data cleaning, scaling, transformation, check correlation between variables and perform sampling.
#
# We use the Fatal Police Shooting data to answer the questions given in this notebook.

# %% [markdown]
# ### Fatal Police Shooting Data

# %% [markdown]
# **About dataset**\
# The dataset consists of following columns
# 1. **id**                         : unqiue identifier of each victim
# 2. **name**                       : name of a victim
# 3. **date**                       : date on fatal shooting
# 4. **manner_of_death**            : manner of death classification
#     * Shot
#     * Shot and Tasered
# 5. **armed**                      : indicates that the victim was armed with some sort of implement that a police officer believed could inflict harm
#     * undetermined: it is not known whether or not the victim had a weapon
#     * unknown: the victim was armed, but it is not known what the object was
#     * unarmed: the victim was not armed
# 6. **age**                        : age of victim
# 7. **gender**                     : the gender of the victim. The Post identifies victims by the gender they identify with if reports indicate that it differs from their biological sex.
#     * M: Male
#     * F: Female
#     * None: Unknown
# 8. **race**                       : race of victim
#     * W: White, non-Hispanic
#     * B: Black, non-Hispanic
#     * A: Asian
#     * N: Native American
#     * H: Hispanic
#     * O: Other
#     * None: unknown
# 9. **city**                       : the municipality where the fatal shooting took place. Note that in some cases this field may contain a county name if a more specific municipality is unavailable or unknown.
# 10. **state**                     : two-letter postal code abbreviation
# 11. **signs_of_mental_illness**   : News reports have indicated the victim had a history of mental health issues, expressed suicidal intentions or was experiencing mental distress at the time of the shooting.
# 12. **threat_level**              : These would include incidents where officers or others were shot at, threatened with a gun, attacked with other weapons or physical force, etc. The attack category is meant to flag the highest level of threat. The other and undetermined categories represent all remaining cases. Other includes many incidents where officers or others faced significant threats.
# 13. **flee**                      : News reports have indicated the victim was moving away from officers
#     * Foot
#     * Car
#     * Not fleeing
# 14. **body_camera**               : News reports have indicated an officer was wearing a body camera and it may have recorded some portion of the incident.

# %% [markdown]
# ## Let's Begin

# %%
# Install the libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load the dataframe 
df = pd.read_csv("week_2_assignment_output.csv")
df.head()

# TODO: Code to fill: 
# 1. '<<__A__>>' --> Path of the csv file == "week_2_assignment_output.csv"
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  age_categories  year
# ...

# %%
# Check the shape of the dataset
df.shape
# Out:
# (4478, 16)

# %% [markdown]
# ### Question: 1 ( 1 Mark )
#
# Check and Handle the missing values (NaN) present in each column with the respective methods

# %%
# Check the dataframe for missing values in the column before handling
df.isnull().sum()

# TODO: Code to fill: 

# 1. '<<__A__>>' --> Use correct method == isnull
# 2. '<<__B__>>' --> Use correct method == sum

## The Above code displays the number of missing elements in each column/attribute
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                      248
# age                        169
# gender                       5
# race                       373
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       179
# body_camera                  0
# age_categories             169
# year                         0
# dtype: int64

# %%
# Handle the missing values 
df['armed'].fillna(df['armed'].mode()[0],inplace=True)
df['age'].fillna(round(df['age'].mean()),inplace=True)
df['gender'].fillna(df['gender'].mode()[0],inplace=True)
df['race'].fillna(df['race'].mode()[0],inplace=True)    
df['flee'].fillna(df['flee'].mode()[0],inplace=True)                     
df['age_categories'].fillna(df['age_categories'].mode()[0],inplace=True)

# write your code here to handle missing values for other columns

# TODO: Code to fill: 

# 1. '<<__C__>>' --> Appropriate filling method == mode(Categorical Data)/mean(Numerical Data)
# 2. '<<__B__>>' --> column_name == the column_names of the columns with missing values
# 3. '<<__A__>>' --> column_name == same names as 'B'

# The filling method for the missing values is determined by the type of data that column stores. if categorical 
# data then use mode if numerical data then mean

# You will have completely filled your null values with appropriate values however, you will run into an error 
# to prevent that from having you can use df.fillna({column_name: df['age_categories'].mode()[0]}, inplace=True) 
# instead of df['Column_name'].fillna(df['Coulmn_name'].mode()[0],inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2136\2922796746.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['armed'].fillna(df['armed'].mode()[0],inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_2136\2922796746.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Check dataframe after handling missing values 
df.isnull().sum()

# TODO: Code to fill: 

# 1. '<<__A__>>' --> Use correct method == isnull/isna
# 2. '<<__B__>>' --> Use correct method == sum
# Out:
# id                         0
# name                       0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# age_categories             0
# year                       0
# dtype: int64

# %% [markdown]
# ### Question: 2 (1 Mark )
# Handle the outliers present in the age column

# %%
# Display the box plot before handling outliers in the age column
sns.boxplot(x = df["age"])
# TODO: Code to fill: 

# 1. '<<__A__>>' --> Display the box plot before handling outliers in the age column == sns.boxplot(x = df['age'])
# Out:
# <Axes: xlabel='age'>

# %%
# Quantile 1 of age column (25 percentage)
Q1 = df['age'].quantile(0.25)
# Quantile 3 of age column (75 percentage)
Q3 = df['age'].quantile(0.75)

# %%
# Inter Quartile Range
IQR = Q3 - Q1
IQR
# Out:
# 18.0

# %%
# Outliers present in upper case
upper_case = Q3 + (1.5*IQR)
print(upper_case)
# Outliers present in lower case
lower_case = Q1 - (1.5*IQR)
print(lower_case)
# Out:
# 72.0
# 0.0

# %%
outliers = []
for i in df['age']:
    if ((i > upper_case) or (i< lower_case)):
        outliers.append(i)

# This piece of code is taken from week2's assignment

# %%
print(outliers)
# Out:
# [75.0, 74.0, 77.0, 83.0, 76.0, 86.0, 76.0, 77.0, 76.0, 76.0, 80.0, 82.0, 86.0, 76.0, 83.0, 73.0, 91.0, 73.0, 79.0, 74.0, 75.0, 82.0, 76.0, 78.0, 84.0, 84.0, 81.0, 89.0, 73.0, 77.0, 76.0, 84.0, 81.0, 80.0, 77.0, 76.0, 74.0, 76.0, 73.0]

# %%
# Remove the outliers in age column
df['age'] = np.clip(df['age'],lower_case,upper_case)

# TODO: Code to fill: 

# 1. '<<__B__>>' --> write the your command to remove outliers outside upper case and lower case == np.clip(df['age'],lower = lower_case,upper = upper_case)

# Reference:
    # https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.clip.html#pandas.DataFrame.clip

# %%
# Display the box plot after handling outliers in the age column
sns.boxplot(x = df["age"])

# TODO: Code to fill: 

# 1  '<<__C__>>' --> Display the box plot after handling outliers in the age column == sns.boxplot(x = df["age"])
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ### Question: 3 ( 1 Mark )
# Plot a bar graph which tells most repeated weapons used to attack the people

# %%
# Get the value count of armed column
armed = df.armed.value_counts()
# set the plot size
plt.figure(figsize=(12, 6))
# Create a bar plot using above variable by filtering upto 7 rows 
sns.barplot(x=armed[:7].index,y=armed[:7].values)
plt.ylabel('Number of Instances')
plt.xlabel('Type of Weapon')
plt.title('Weapon vs Count',color = 'blue',fontsize=15)

# TODO: Code to fill: 

# 1. '<<__A__>>' --> Set the plot size == plt.figure(figsize=(12, 6))
# 2. '<<__B__>>' --> set a name for y label == 'Number of Instances'
# 3. '<<__C__>>' --> set a name for x label == 'Type of Weapon'
# 4. '<<__D__>>' --> set a title for the graph with a  fontsize 15 in the colour of blue == 'Weapon vs Count',color = 'blue',fontsize=15
# Out:
# Text(0.5, 1.0, 'Weapon vs Count')

# %% [markdown]
# ### Question: 4 ( 2 Marks )
# Generate a bar plot to identify days in which the count of attacks are reported most

# %%
# Create a new columns day, month, year using date column with the help of pandas to_datetime method
df['day'] = pd.to_datetime(df['date']).dt.day
df['month'] = pd.to_datetime(df['date']).dt.month
df['year'] = pd.to_datetime(df['date']).dt.year 

# we dont have to do this again, we already have a year column from previous week

# %%
#Plot a bar graph in which days the count of attcks are more
df['day'].value_counts().plot.bar(figsize=(12,6))

# TODO: Code to fill: 

# 1. '<<__A__>>' --> Fill the column name for which you want to plot a bar graph == day
# 2. '<<__B__>>' --> write your method here to count the values == count_values()
# 3. '<<__C__>>' --> fill the type of plot == bar
# 4. '<<__D__>>' --> Set plot size (12,6) == "figsize=(12,6)"


# The 5th day of the month shows the highest attack count.

# References:
    # https://pandas.pydata.org/docs/reference/frame.html#plotting
# Out:
# <Axes: xlabel='day'>

# %% [markdown]
# ### Question: 5 ( 2 Marks )
# Display the Top 10 states where the high number of cases recorded

# %%
# Write your code here
state = df.state.value_counts()

# Display the Top 10 states using bar chart
plt.figure(figsize=(10,7))
sns.barplot(x=state[:10].index, y=state[:10].values)
plt.ylabel('Number of cases reported')
plt.xlabel('States')
plt.title('Top 10 states',color = 'blue',fontsize=15)


# TODO: Code to fill: 

# 1. '<<__A__>>' --> Fill the column name == state
# 2. '<<__B__>>' --> write your method here to count the values == value_counts()
# 3. '<<__C__>>' --> Provide x axis values from state dataframe created in previous step == state[:10].index
# 4. '<<__D__>>' --> Provide y axis values from state dataframe created in previous step == state[:10].values
# Out:
# Text(0.5, 1.0, 'Top 10 states')

# %% [markdown]
# ### Question: 6 ( 1 Mark )
# Drop the features that have more unique string values and not relevant to the model.

# %%
# Drop the features that have more unique string values and not relevant to the model.
df.drop(columns=['manner_of_death','signs_of_mental_illness','flee','body_camera'],axis=1,inplace=True)

#References:
 #   https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html

# %%
#Display the top 5 rows of dataset after droping the unnecessary features
df.head(5)

# TODO: Code to fill: 

# 1. '<<__A__>>' --> Fill appropriate method for removing features == drop
# 2. '<<__B__>>' --> column names == 'manner_of_death','signs_of_mental_illness','flee','body_camera'
# 3. '<<__C__>>' --> Give the axis for removing features == 1 for dropping column and 0 for tuple/instance/example
# 3. '<<__D__>>' --> Use the correct method to get top 5 rows of dataset after droping the unnecessary features == head
# Out:
#    id                name        date       armed   age gender race  \
# 0   3          Tim Elliot  2015-01-02         gun  53.0      M    A
# 1   4    Lewis Lee Lembke  2015-01-02         gun  47.0      M    W
# 2   5  John Paul Quintero  2015-01-03     unarmed  23.0      M    H
# 3   8     Matthew Hoffman  2015-01-04  toy weapon  32.0      M    W
# 4   9   Michael Rodriguez  2015-01-04    nail gun  39.0      M    H
#
#             city state threat_level  age_categories  year  day  month
# 0        Shelton    WA       attack  Senior Citizen  2015    2      1
# 1          Aloha    OR       attack           Adult  2015    2      1
# 2        Wichita    KS        other           Youth  2015    3      1
# 3  San Francisco    CA       attack           Youth  2015    4      1
# 4          Evans    CO       attack           Adult  2015    4      1

# %% [markdown]
# ### Question: 7 ( 2 Marks )
# Create a line plot that shows the number of attacks every year according to race

# %%
# Write your code here
pd.crosstab(df['year'],df['race']).plot.line(figsize=(12,6))


# TODO: Code to fill: 

# 1. '<<__A__>>' --> Fill the exact column name == year
# 2. '<<__B__>>' --> Fill the exact column name == race
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## Thank you!
